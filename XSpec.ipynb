# %%
import sys
import os

# %%
# check the installation #
if not 'HEADAS' in os.environ:
    raise RuntimeError('Heasoft is not initalized')

try:
    sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))
    import heasoftpy as hsp
except ImportError:
    raise RuntimeError('Please ensure heasoftpy is in your PYTHONPATH')
    
if not hasattr(hsp, 'ftlist'):
    raise RuntimeError('Heasoftpy is not full installed. Please run the install.py script')

# %%
print(hsp.__version__)
# Out:
# 1.2.1

# %%
from xspec import *
import numpy as np
import os
from scipy.optimize import fsolve

# %%
insts = ["FPMA",
        "FPMB",
        "pn",
        "m1",
        "m2"]
logNH = np.array([20,21,22,23,24,25])-22
logFs = [-12,-13,-13.5,-14]#np.linspace(-14,-13,3) #for 3-24 keV
print(logFs)
nh_gal = 0.0338 #average nH_gal in NEP sample
z = 0.5 #Mean redshift
exp = [360, #mean exposure across field
        360,
        249,
        249,
        249]
# Out:
# [-12, -13, -13.5, -14]

# %%
Fit.statMethod = 'cstat'
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.

# %%
def set_pars(m,pars,par_vals,
        par_fixed,one_epoch,
        par_var):
    """
    par_vals: the initial values for the parameters
    par_fixed: is the parameter fixed to the initial value?
    par_var: (if multiple_epochs are loaded) are pars linked across epochs?
    """
    n_eps = AllData.nGroups
    for i_par,par in enumerate(pars):
        #If the par is fixed, fix it
        if par_fixed[i_par]:
            m(par).values = [par_vals[i_par],-1]
        #else, if the par is free, free it
        else:
            m(par).values = par_vals[i_par]
            #THEN go through and unlink the parameters (if applicable)
            if not one_epoch and par_var[i_par]:
                for i_ep in range(1,n_eps+1):
                    #unlink the parameter, set it to the starter value
                    AllModels(i_ep)(par).values = par_vals[i_par]

# %%
def mk_clumpy(nh_gal,z,
        pars=[1,3,4,10,11,20,25],
        par_vals=[1.0,1,1.8,1.0e-4,1.0e-3,0.6,1.0e-4],
        par_fixed=[True,False,False,False,False,True,False],
        one_epoch=True,
        par_var=[False,False,False,False,False,False,False],
        bxa = False):
    """
    default pars: constant, nH, Gamma, norm, omni
    """
    Xset.abund="wilm" #Abundances for the uxclumpy model
    m = model.Model("constant*phabs(atable{uxclumpy-cutoff.fits} + constant*atable{uxclumpy-cutoff-omni.fits} + mekal)")
    m(2).values = [nh_gal,-1]#ISM absorption
    m(5).values = [400,-1] #E-cutoff
    m(6).values = [45,-1] #TORsigma
    m(7).values = [0.4,-1] #CTKcover
    m(8).values = [90.0,-1] #Theta_inc
    m(9).values = [z,-1,0.0,0.0,10.0,10.0] #Redshift
    m(11).values = [1.0e-5,1.0e-5,1.0e-5,1.0e-5,0.1,0.1]
    m(21).values = [1.0,-1] #nH for soft excess
    m(23).values = [z,-1] #redshift

    ######## omni component
    if AllData.nGroups == 0:
        n_spec = 1
    else:
        n_spec = AllData.nGroups
    for i_model in range(1,n_spec+1):
        AllModels(i_model)(12).link = m(3)
        AllModels(i_model)(13).link = m(4)
        AllModels(i_model)(14).link = m(5)
        AllModels(i_model)(15).link = m(6)
        AllModels(i_model)(16).link = m(7)
        AllModels(i_model)(17).link = m(8)
        AllModels(i_model)(18).link = m(9)
        AllModels(i_model)(19).link = m(10)
    set_pars(m, pars,par_vals,par_fixed,one_epoch,
        par_var)
    
    m(pars[0]).values = par_vals[0]
    m(1).values = 1.0,-1

# %%
mk_clumpy(nh_gal,z)
# Out:
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# ========================================================================
# Model constant<1>*phabs<2>(atable{uxclumpy-cutoff.fits}<3> + constant<4>*atable{uxclumpy-cutoff-omni.fits}<5> + mekal<6>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   constant   factor              1.00000      +/-  0.0
#    2    2   phabs      nH         10^22    1.00000      +/-  0.0
#    3    3   torus      nH                  10.0000      +/-  0.0
#    4    3   torus      PhoIndex            2.00000      +/-  0.0
#    5    3   torus      Ecut                100.000      +/-  0.0
#    6    3   torus      TORsigma            28.0000      +/-  0.0
#    7    3   torus      CTKcover            0.400000     +/-  0.0
#    8    3   torus      Theta_inc           18.2000      +/-  0.0
#    9    3   torus      z                   0.0          frozen
#   10    3   torus      norm                1.00000      +/-  0.0
#   11    4   constant   factor              1.00000      +/-  0.0
#   12    5   scat       nH                  10.0000      +/-  0.0
#   13    5   scat       PhoIndex            2.00000      +/-  0.0
#   14    5   scat       Ecut                100.000      +/-  0.0
#   15    5   scat       TORsigma            28.0000      +/-  0.0
#   16    5   scat       CTKcover            0.400000     +/-  0.0
#   17    5   scat       Theta_inc           18.2000      +/-  0.0
#   18    5   scat       z                   0.0          frozen
#   19    5   scat       norm                1.00000      +/-  0.0
#   20    6   mekal      kT         keV      1.00000      +/-  0.0
#   21    6   mekal      nH         cm-3     1.00000      frozen
#   22    6   mekal      Abundanc            1.00000      frozen
#   23    6   mekal      Redshift            0.0          frozen
#   24    6   mekal      switch              1            frozen
#   25    6   mekal      norm                1.00000      +/-  0.0
# ________________________________________________________________________

# %%
m = AllModels(1)
m(25).values=1.0e-10
for logNH in logNH:
    m(3).values = 10.0**logNH
    for F in logFs:
        print("######################################################################")
        print("FLUX: {}".format(F))
        def flux_func(x, F = 10**float(F), i_norm=10):
            #Function for calculating the norm that yields a given flux
            if x < 0:
                x = 1.0e-10
            AllModels(1)(i_norm).values = x
            print(x)
            AllModels.calcFlux("3.0 24.0")
            flux = AllModels(1).flux[0]
            return flux-F
        int_norm = fsolve(flux_func,1.0e-5)[0]
        print("FLUX OF SPECTRUM: {}".format(AllModels(1).flux[0]))
        #Let’s start with 100 itterations
        for i in range(0,10):
            fk_s = [] #For fakeitsettings
            for i_i,inst in enumerate(insts): #FakeItSettings
                if os.path.exists("simulations/spec_files/{}_nH{}_F{}_{}s_{}.pha".format(inst,logNH+22,-F,exp[i_i],i)):
                    os.remove("simulations/spec_files/{}_nH{}_F{}_{}s_{}.pha".format(inst,logNH+22,-F,exp[i_i],i))
                fk_s.append(FakeitSettings(response="simulations/inst_files/{}.rmf".format(inst),
                    arf="simulations/inst_files/{}.arf".format(inst),
                    background="simulations/inst_files/{}_bgd.pha".format(inst),
                    exposure=exp[i_i]*1000,
                    fileName="simulations/spec_files/{}_nH{}_F{}_{}s_{}.pha".format(inst,logNH+22,-F,exp[i_i],i)))
            AllData.fakeit(len(insts),fk_s)
            #NuSTAR
            AllData(1).ignore("1.0e-60-3.0")
            AllData(1).ignore("24.0-200.0")
            AllData(2).ignore("1.0e-60-3.0")
            AllData(2).ignore("24.0-200.0")
            #XMM
            AllData(3).ignore("1.0e-60-0.1")
            AllData(3).ignore("6.0-200.0")
            AllData(4).ignore("1.0e-60-0.1")
            AllData(4).ignore("6.0-200.0")
            AllData(5).ignore("1.0e-60-0.1")
            AllData(5).ignore("6.0-200.0")
            if os.path.exists("simulations/fit_files/nH{}_F{}_{}s_{}_true.py".format(logNH+22,-F,exp[0],i)):
                os.remove("simulations/fit_files/nH{}_F{}_{}s_{}_true.py".format(logNH+22,-F,exp[0],i))
            print("Saving simulations/fit_files/nH{}_F{}_{}s_{}_true.py".format(logNH+22,-F,exp[0],i))
            Xset.save("simulations/fit_files/nH{}_F{}_{}s_{}_true.py".format(logNH+22,-F,exp[0],i))
            AllData.clear()
# Out:
# ######################################################################
# FLUX: -12
# [1.e-05]
# [1.e-05] Model Flux 1.7392e-06 photons (2.2113e-14 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
#  Model Flux 1.7392e-06 photons (2.2113e-14 ergs/cm^2/s) range (3.0000 - 24.000 keV)
# [1.e-05]
# [1.00000001e-05]
#  Model Flux 1.7392e-06 photons (2.2113e-14 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#  Model Flux 1.7392e-06 photons (2.2113e-14 ergs/cm^2/s) range (3.0000 - 24.000 keV)
# [0.00066896]
# [0.00045222] Model Flux 0.00011634 photons (1.4793e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00045222] Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00066896]
#  Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
# [0.00045222]
# [0.00034385] Model Flux 0.00011634 photons (1.4793e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#  Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00045222]
#  Model Flux 5.9801e-05 photons (7.6036e-13 ergs/cm^2/s) range (3.0000 - 24.000 keV)
# [0.00042512]
# [0.00045222] Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00044544]
# [0.00045222] Model Flux 7.3935e-05 photons (9.4008e-13 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#  Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00045052] Model Flux 7.7469e-05 photons (9.8501e-13 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#  Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
# [0.00045222] Model Flux 7.8352e-05 photons (9.9624e-13 ergs/cm^2/s) range (3.0000 - 24.000 keV)
#
#  Model Flux 7.8648e-05 photons (1e-12 ergs/cm^2/s) range (3.0000 - 24.000 keV)
# FLUX OF SPECTRUM: 1.000002425386162e-12
# /uufs/chpc.utah.edu/sys/installdir/r8/python/3.10.3/lib/python3.10/site-packages/scipy-1.8.0-py3.10-linux-x86_64.egg/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH20_F12_360s_0.pha & 360000, ,  & simulations/spec_files/FPMB_nH20_F12_360s_0.pha & 360000, ,  & simulations/spec_files/pn_nH20_F12_249s_0.pha & 249000, ,  & simulations/spec_files/m1_nH20_F12_249s_0.pha & 249000, ,  & simulations/spec_files/m2_nH20_F12_249s_0.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3682.85     using 4096 bins, spectrum 1.
#                  C-Statistic                 3458.38     using 4096 bins, spectrum 2.
#                  C-Statistic                 2353.51     using 4096 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                         10969.82     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                59934.39     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
#     35 channels (1-35) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                 3638.19     using 4061 bins, spectrum 1.
#                  C-Statistic                 3458.38     using 4096 bins, spectrum 2.
#                  C-Statistic                 2353.51     using 4096 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                         10925.16     with 13848 d.o.f.
#
# Test statistic : Chi-Squared                59488.71     using 13853 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13848 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                 3458.38     using 4096 bins, spectrum 2.
#                  C-Statistic                 2353.51     using 4096 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          7834.84     with 10311 d.o.f.
#
# Test statistic : Chi-Squared                37868.25     using 10316 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10311 degrees of freedom
#  Current data and model not fit yet.
#
#     35 channels (1-35) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                 3413.39     using 4061 bins, spectrum 2.
#                  C-Statistic                 2353.51     using 4096 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          7789.86     with 10276 d.o.f.
#
# Test statistic : Chi-Squared                37804.91     using 10281 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10276 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 2353.51     using 4096 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          4942.76     with 6739 d.o.f.
#
# Test statistic : Chi-Squared                18886.14     using 6744 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6739 degrees of freedom
#  Current data and model not fit yet.
#
#     19 channels (1-19) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 2342.11     using 4077 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          4931.36     with 6720 d.o.f.
#
# Test statistic : Chi-Squared                18873.96     using 6725 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6720 degrees of freedom
#  Current data and model not fit yet.
#
#   2897 channels (1200-4096) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 1254.65     using 1180 bins, spectrum 3.
#                  C-Statistic                  749.62     using 800 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          3843.89     with 3823 d.o.f.
#
# Test statistic : Chi-Squared                17776.62     using 3828 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3823 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 1254.65     using 1180 bins, spectrum 3.
#                  C-Statistic                  744.04     using 793 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          3838.31     with 3816 d.o.f.
#
# Test statistic : Chi-Squared                17770.68     using 3821 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3816 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 1254.65     using 1180 bins, spectrum 3.
#                  C-Statistic                  369.81     using 392 bins, spectrum 4.
#                  C-Statistic                  725.46     using 800 bins, spectrum 5.
# Total fit statistic                          3464.08     with 3415 d.o.f.
#
# Test statistic : Chi-Squared                17431.87     using 3420 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3415 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 1254.65     using 1180 bins, spectrum 3.
#                  C-Statistic                  369.81     using 392 bins, spectrum 4.
#                  C-Statistic                  719.02     using 793 bins, spectrum 5.
# Total fit statistic                          3457.64     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                17423.36     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  547.87     using 524 bins, spectrum 1.
#                  C-Statistic                  566.29     using 524 bins, spectrum 2.
#                  C-Statistic                 1254.65     using 1180 bins, spectrum 3.
#                  C-Statistic                  369.81     using 392 bins, spectrum 4.
#                  C-Statistic                  389.57     using 392 bins, spectrum 5.
# Total fit statistic                          3128.18     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                17123.21     using 3012 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3
#
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# Saving simulations/fit_files/nH20_F12_360s_0_true.py
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH20_F12_360s_1.pha & 360000, ,  & simulations/spec_files/FPMB_nH20_F12_360s_1.pha & 360000, ,  & simulations/spec_files/pn_nH20_F12_249s_1.pha & 249000, ,  & simulations/spec_files/m1_nH20_F12_249s_1.pha & 249000, ,  & simulations/spec_files/m2_nH20_F12_249s_1.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3771.26     using 4096 bins, spectrum 1.
#                  C-Statistic                 3463.75     using 4096 bins, spectrum 2.
#                  C-Statistic                 2395.32     using 4096 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                         11184.26     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                58557.82     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
#     35 channels (1-35) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                 3742.08     using 4061 bins, spectrum 1.
#                  C-Statistic                 3463.75     using 4096 bins, spectrum 2.
#                  C-Statistic                 2395.32     using 4096 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                         11155.08     with 13848 d.o.f.
#
# Test statistic : Chi-Squared                58510.95     using 13853 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13848 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                 3463.75     using 4096 bins, spectrum 2.
#                  C-Statistic                 2395.32     using 4096 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          7984.94     with 10311 d.o.f.
#
# Test statistic : Chi-Squared                37381.44     using 10316 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10311 degrees of freedom
#  Current data and model not fit yet.
#
#     35 channels (1-35) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                 3414.63     using 4061 bins, spectrum 2.
#                  C-Statistic                 2395.32     using 4096 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          7935.82     with 10276 d.o.f.
#
# Test statistic : Chi-Squared                37324.95     using 10281 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10276 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 2395.32     using 4096 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          5083.92     with 6739 d.o.f.
#
# Test statistic : Chi-Squared                18701.11     using 6744 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6739 degrees of freedom
#  Current data and model not fit yet.
#
#     19 channels (1-19) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 2380.28     using 4077 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          5068.87     with 6720 d.o.f.
#
# Test statistic : Chi-Squared                18686.29     using 6725 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6720 degrees of freedom
#  Current data and model not fit yet.
#
#   2897 channels (1200-4096) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 1239.16     using 1180 bins, spectrum 3.
#                  C-Statistic                  779.75     using 800 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          3927.75     with 3823 d.o.f.
#
# Test statistic : Chi-SSaving simulations/fit_files/nH20_F12_360s_1_true.py
# quared                17471.60     using 3828 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3823 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 1239.16     using 1180 bins, spectrum 3.
#                  C-Statistic                  771.63     using 793 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          3919.63     with 3816 d.o.f.
#
# Test statistic : Chi-Squared                17464.69     using 3821 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3816 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 1239.16     using 1180 bins, spectrum 3.
#                  C-Statistic                  373.19     using 392 bins, spectrum 4.
#                  C-Statistic                  774.18     using 800 bins, spectrum 5.
# Total fit statistic                          3521.19     with 3415 d.o.f.
#
# Test statistic : Chi-Squared                17117.25     using 3420 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 5
#
#  Null hypothesis probability of 0.00e+00 with 3415 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 1239.16     using 1180 bins, spectrum 3.
#                  C-Statistic                  373.19     using 392 bins, spectrum 4.
#                  C-Statistic                  763.97     using 793 bins, spectrum 5.
# Total fit statistic                          3510.98     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                17106.27     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  571.94     using 524 bins, spectrum 1.
#                  C-Statistic                  562.73     using 524 bins, spectrum 2.
#                  C-Statistic                 1239.16     using 1180 bins, spectrum 3.
#                  C-Statistic                  373.19     using 392 bins, spectrum 4.
#                  C-Statistic                  407.18     using 392 bins, spectrum 5.
# Total fit statistic                          3154.19     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                16789.90     using 3012 bins.
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH20_F12_360s_2.pha & 360000, ,  & simulations/spec_files/FPMB_nH20_F12_360s_2.pha & 360000, ,  & simulations/spec_files/pn_nH20_F12_249s_2.pha & 249000, ,  & simulations/spec_files/m1_nH20_F12_249s_2.pha & 249000, ,  & simulations/spec_files/m2_nH20_F12_249s_2.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3660.31     using 4096 bins, spectrum 1.
#                  C-Statistic                 3325.19     using 4096 bins, spectrum 2.
#                  C-Statistic                 2319.82     using 4096 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                         10870.66     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                58498.91     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
#     35 channels (1-35) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                 3619.81     using 4061 bins, spectrum 1.
#                  C-Statistic                 3325.19     using 4096 bins, spectrum 2.
#                  C-Statistic                 2319.82     using 4096 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                         10830.16     with 13848 d.o.f.
#
# Test statistic : Chi-Squared                58298.09     using 13853 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13848 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                 3325.19     using 4096 bins, spectrum 2.
#                  C-Statistic                 2319.82     using 4096 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          7743.32     with 10311 d.o.f.
#
# Test statistic : Chi-Squared                37223.49     using 10316 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10311 degrees of freedom
#  Current data and model not fit yet.
#
#     35 channels (1-35) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                 3298.46     using 4061 bins, spectrum 2.
#                  C-Statistic                 2319.82     using 4096 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          7716.59     with 10276 d.o.f.
#
# Test statistic : Chi-Squared                37200.12     using 10281 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10276 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 2319.82     using 4096 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          4935.70     with 6739 d.o.f.
#
# Test statistic : Chi-Squared                18647.31     using 6744 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6739 degrees of freedom
#  Current data and model not fit yet.
#
#     19 channels (1-19) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 2304.20     using 4077 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          4920.09     with 6720 d.o.f.
#
# Test statistic : Chi-Squared                18631.49     using 6725 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6720 degrees of freedom
#  Current data and model not fit yet.
#
#   2897 channels (1200-4096) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 1208.04     using 1180 bins, spectrum 3.
#                  C-Statistic                  768.69     using 800 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          3823.92     with 3823 d.o.f.
#
# Test statistic : Chi-Squared                17485.19     using 3828 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3823 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 1208.04     using 1180 bins, spectrum 3.
#                  C-Statistic                  759.55     using 793 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          3814.79     with 3816 d.o.f.
#
# Test statistic : Chi-Squared                17475.90     using 3821 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3816 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 1208.04     using 1180 bins, spectrum 3.
#                  C-Statistic                  370.56     using 392 bins, spectrum 4.
#                  C-Statistic                  796.65     using 800 bins, spectrum 5.
# Total fit statistic                          3425.79     with 3415 d.o.f.
#
# Test statistic : Chi-Squared                17136.73     using 3420 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3415 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 1208.04     using 1180 bins, spectrum 3.
#                  C-Statistic                  370.56     using 392 bins, spectrum 4.
#                  C-Statistic                  791.88     using 793 bins, spectrum 5.
# Total fit statistic                          3421.03     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                17131.02     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  532.97     using 524 bins, spectrum 1.
#                  C-Statistic                  517.58     using 524 bins, spectrum 2.
#                  C-Statistic                 1208.04     using 1180 bins, spectrum 3.
#                  C-Statistic                  370.56     using 392 bins, spectrum 4.
#                  C-Statistic                  408.20     using 392 bins, spectrum 5.
# Total fit statistic                          3037.34     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                16807.05     using 3012 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3
#
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# Saving simulations/fit_files/nH20_F12_360s_2_true.py
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH20_F12_360s_3.pha & 360000, ,  & simulations/spec_files/FPMB_nH20_F12_360s_3.pha & 360000, ,  & simulations/spec_files/pn_nH20_F12_249s_3.pha & 249000, ,  & simulations/spec_files/m1_nH20_F12_249s_3.pha & 249000, ,  & simulations/spec_files/m2_nH20_F12_249s_3.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3792.21     using 4096 bins, spectrum 1.
#                  C-Statistic                 3579.62     using 4096 bins, spectrum 2.
#                  C-Statistic                 2438.26     using 4096 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                         11427.36     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                60489.37     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
#     35 channels (1-35) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                 3758.60     using 4061 bins, spectrum 1.
#                  C-Statistic                 3579.62     using 4096 bins, spectrum 2.
#                  C-Statistic                 2438.26     using 4096 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                         11393.75     with 13848 d.o.f.
#
# Test statistic : Chi-Squared                60398.64     using 13853 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13848 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                 3579.62     using 4096 bins, spectrum 2.
#                  C-Statistic                 2438.26     using 4096 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          8188.27     with 10311 d.o.f.
#
# Test statistic : Chi-Squared                38304.18     using 10316 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10311 degrees of freedom
#  Current data and model not fit yet.
#
#     35 channels (1-35) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                 3526.91     using 4061 bins, spectrum 2.
#                  C-Statistic                 2438.26     using 4096 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          8135.55     with 10276 d.o.f.
#
# Test statistic : Chi-Squared                38242.36     using 10281 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10276 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 2438.26     using 4096 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          5220.96     with 6739 d.o.f.
#
# Test statistic : Chi-Squared                19478.98     using 6744 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6739 degrees of freedom
#  Current data and model not fit yet.
#
#     19 channels (1-19) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 2427.90     using 4077 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          5210.60     with 6720 d.o.f.
#
# Test statistic : Chi-Squared                19468.81     using 6725 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6720 degrees of freedom
#  Current data and model not fit yet.
#
#   2897 channels (1200-4096) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 1280.71     using 1180 bins, spectrum 3.
#                  C-Statistic                  774.20     using 800 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          4063.41     with 3823 d.o.f.
#
# Test statistic : Chi-Squared                18307.81     using 3828 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3823 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 1280.71     using 1180 bins, spectrum 3.
#                  C-Statistic                  765.12     using 793 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          4054.33     with 3816 d.o.f.
#
# Test statistic : Chi-Squared                18300.14     using 3821 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3816 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 1280.71     using 1180 bins, spectrum 3.
#                  C-Statistic                  361.54     using 392 bins, spectrum 4.
#                  C-Statistic                  843.07     using 800 bins, spectrum 5.
# Total fit statistic                          3650.74     with 3415 d.o.f.
#
# Test statistic : Chi-Squared                17958.60     using 3420 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3415 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 1280.71     using 1180 bins, spectrum 3.
#                  C-Statistic                  361.54     using 392 bins, spectrum 4.
#                  C-Statistic                  835.39     using 793 bins, spectrum 5.
# Total fit statistic                          3643.07     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                17948.72     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  553.12     using 524 bins, spectrum 1.
#                  C-Statistic                  612.31     using 524 bins, spectrum 2.
#                  C-Statistic                 1280.71     using 1180 bins, spectrum 3.
#                  C-Statistic                  361.54     using 392 bins, spectrum 4.
#                  C-Statistic                  470.58     using 392 bins, spectrum 5.
# Total fit statistic                          3278.26     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                17646.77     using 3012 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3
#
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# Saving simulations/fit_files/nH20_F12_360s_3_true.py
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH20_F12_360s_4.pha & 360000, ,  & simulations/spec_files/FPMB_nH20_F12_360s_4.pha & 360000, ,  & simulations/spec_files/pn_nH20_F12_249s_4.pha & 249000, ,  & simulations/spec_files/m1_nH20_F12_249s_4.pha & 249000, ,  & simulations/spec_files/m2_nH20_F12_249s_4.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3740.12     using 4096 bins, spectrum 1.
#                  C-Statistic                 3356.08     using 4096 bins, spectrum 2.
#                  C-Statistic                 2373.47     using 4096 bins, spectrum 3.
#                  C-Statistic                  833.19     using 800 bins, spectrum 4.
#                  C-Statistic                  856.98     using 800 bins, spectrum 5.
# Total fit statistic                         11159.84     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                61916.11     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
# ...
#
# Fit statistic  : C-Statistic                  571.71     using 524 bins, spectrum 1.
#                  C-Statistic                  548.17     using 524 bins, spectrum 2.
#                  C-Statistic                 1230.41     using 1180 bins, spectrum 3.
#                  C-Statistic                  401.23     using 392 bins, spectrum 4.
#                  C-Statistic                  700.90     using 793 bins, spectrum 5.
# Total fit statistic                          3452.42     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                13065.08     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  571.71     using 524 bins, spectrum 1.
#                  C-Statistic                  548.17     using 524 bins, spectrum 2.
#                  C-Statistic                 1230.41     using 1180 bins, spectrum 3.
#                  C-Statistic                  401.23     using 392 bins, spectrum 4.
#                  C-Statistic                  410.39     using 392 bins, spectrum 5.
# Total fit statistic                          3161.92     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                12801.75     using 3012 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# Saving simulations/fit_files/nH22_F13_360s_4_true.py
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH22_F13_360s_5.pha & 360000, ,  & simulations/spec_files/FPMB_nH22_F13_360s_5.pha & 360000, ,  & simulations/spec_files/pn_nH22_F13_249s_5.pha & 249000, ,  & simulations/spec_files/m1_nH22_F13_249s_5.pha & 249000, ,  & simulations/spec_files/m2_nH22_F13_249s_5.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3724.26     using 4096 bins, spectrum 1.
#                  C-Statistic                 3364.71     using 4096 bins, spectrum 2.
#                  C-Statistic                 2149.42     using 4096 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                         10767.34     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                53642.16     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
#     35 channels (1-35) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                 3687.23     using 4061 bins, spectrum 1.
#                  C-Statistic                 3364.71     using 4096 bins, spectrum 2.
#                  C-Statistic                 2149.42     using 4096 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                         10730.32     with 13848 d.o.f.
#
# Test statistic : Chi-Squared                53342.00     using 13853 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13848 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     1
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                 3364.71     using 4096 bins, spectrum 2.
#                  C-Statistic                 2149.42     using 4096 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          7570.88     with 10311 d.o.f.
#
# Test statistic : Chi-Squared                32175.90     using 10316 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10311 degrees of freedom
#  Current data and model not fit yet.
#
#     35 channels (1-35) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                 3324.79     using 4061 bins, spectrum 2.
#                  C-Statistic                 2149.42     using 4096 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          7530.96     with 10276 d.o.f.
#
# Test statistic : Chi-Squared                32118.27     using 10281 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 10276 degrees of freedom
#  Current data and model not fit yet.
#
#   3537 channels (560-4096) ignored in spectrum #     2
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 2149.42     using 4096 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          4787.83     with 6739 d.o.f.
#
# Test statistic : Chi-Squared                14165.76     using 6744 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6739 degrees of freedom
#  Current data and model not fit yet.
#
#     19 channels (1-19) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 2139.73     using 4077 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          4778.13     with 6720 d.o.f.
#
# Test statistic : Chi-Squared                14160.18     using 6725 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 6720 degrees of freedom
#  Current data and model not fit yet.
#
#   2897 channels (1200-4096) ignored in spectrum #     3
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 1346.78     using 1180 bins, spectrum 3.
#                  C-Statistic                  751.51     using 800 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          3985.19     with 3823 d.o.f.
#
# Test statistic : Chi-Squared                13251.96     using 3828 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3823 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 1346.78     using 1180 bins, spectrum 3.
#                  C-Statistic                  747.32     using 793 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          3981.00     with 3816 d.o.f.
#
# Test statistic : Chi-Squared                13250.15     using 3821 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3816 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     4
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 1346.78     using 1180 bins, spectrum 3.
#                  C-Statistic                  414.92     using 392 bins, spectrum 4.
#                  C-Statistic                  777.44     using 800 bins, spectrum 5.
# Total fit statistic                          3648.60     with 3415 d.o.f.
#
# Test statistic : Chi-Squared                12939.62     using 3420 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3415 degrees of freedom
#  Current data and model not fit yet.
#
#      7 channels (1-7) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 1346.78     using 1180 bins, spectrum 3.
#                  C-Statistic                  414.92     using 392 bins, spectrum 4.
#                  C-Statistic                  772.86     using 793 bins, spectrum 5.
# Total fit statistic                          3644.02     with 3408 d.o.f.
#
# Test statistic : Chi-Squared                12937.22     using 3413 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3408 degrees of freedom
#  Current data and model not fit yet.
#
#    401 channels (400-800) ignored in spectrum #     5
#
# Fit statistic  : C-Statistic                  527.79     using 524 bins, spectrum 1.
#                  C-Statistic                  581.67     using 524 bins, spectrum 2.
#                  C-Statistic                 1346.78     using 1180 bins, spectrum 3.
#                  C-Statistic                  414.92     using 392 bins, spectrum 4.
#                  C-Statistic                  456.47     using 392 bins, spectrum 5.
# Total fit statistic                          3327.63     with 3007 d.o.f.
#
# Test statistic : Chi-Squared                12656.45     using 3012 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 3007 degrees of freedom
#  Current data and model not fit yet.
#
# Saving simulations/fit_files/nH22_F13_360s_5_true.py
# xsFakeit cmd string:
# fakeit 1 simulations/inst_files/FPMA_bgd.pha 2 simulations/inst_files/FPMB_bgd.pha 3 simulations/inst_files/pn_bgd.pha 4 simulations/inst_files/m1_bgd.pha 5 simulations/inst_files/m2_bgd.pha & simulations/inst_files/FPMA.rmf & simulations/inst_files/FPMA.arf & simulations/inst_files/FPMB.rmf & simulations/inst_files/FPMB.arf & simulations/inst_files/pn.rmf & simulations/inst_files/pn.arf & simulations/inst_files/m1.rmf & simulations/inst_files/m1.arf & simulations/inst_files/m2.rmf & simulations/inst_files/m2.arf & y & / & simulations/spec_files/FPMA_nH22_F13_360s_6.pha & 360000, ,  & simulations/spec_files/FPMB_nH22_F13_360s_6.pha & 360000, ,  & simulations/spec_files/pn_nH22_F13_249s_6.pha & 249000, ,  & simulations/spec_files/m1_nH22_F13_249s_6.pha & 249000, ,  & simulations/spec_files/m2_nH22_F13_249s_6.pha & 249000, ,
#
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMA) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF TELESCOPE keyword (NuSTAR) is not consistent with that in spectrum (UNKNOWN)
# Warning: RMF INSTRUMENT keyword (FPMB) is not consistent with that in spectrum (UNKNOWN)
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 5 spectra  in use
#
#
# Fit statistic  : C-Statistic                 3741.39     using 4096 bins, spectrum 1.
#                  C-Statistic                 3436.58     using 4096 bins, spectrum 2.
#                  C-Statistic                 2212.52     using 4096 bins, spectrum 3.
#                  C-Statistic                  787.08     using 800 bins, spectrum 4.
#                  C-Statistic                  716.94     using 800 bins, spectrum 5.
# Total fit statistic                         10894.51     with 13883 d.o.f.
#
# Test statistic : Chi-Squared                52541.05     using 13888 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1 2 3 4 5
#
#  Null hypothesis probability of 0.00e+00 with 13883 degrees of freedom
#  Current data and model not fit yet.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/local/u0881097/2226036/ipykernel_3687420/1639153454.py in <cell line: 3>()
#      28                     exposure=exp[i_i]*1000,
#      29                     fileName="simulations/spec_files/{}_nH{}_F{}_{}s_{}.pha".format(inst,logNH+22,-F,exp[i_i],i)))
# ---> 30             AllData.fakeit(len(insts),fk_s)
#      31             #NuSTAR
#      32             AllData(1).ignore("1.0e-60-3.0")
#
# /uufs/chpc.utah.edu/sys/installdir/r8/heasoft/6.31.1/x86_64-pc-linux-gnu-libc2.28/lib/python/xspec/data.py in fakeit(self, nSpectra, settings, applyStats, filePrefix, noWrite)
#     551                 curRecord.fileName = filePrefix + rootName + insertion + ".fak"
#     552
# --> 553         _pyXspec.doFakeit(intSettings, int(applyStats), filePrefix, int(noWrite))
#     554
#     555     def ignore(self, ignoreRange):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Load your simulated data
s = Spectrum(["spec_files/FPMA_nH20_F12_360s_6_bkg.pha", "spec_files/FPMA_nH20_F12_360s_6.pha"])

s1 = Spectrum("file1")
b1 = s1.background
r1 = s1.response
arfFileName = r1.arf

# Define and fit a model (if needed)
#m = xspec.Model("your_model")
#m.fit(s)

# Plot the data and model
xspec.Plot.xAxis = "keV"  # Set the x-axis units
xspec.Plot("data")
xspec.Plot("model")

# Customize the plot using matplotlib
plt.xlabel("Energy (keV)")
plt.ylabel("Counts/s/keV")
plt.title("XSPEC Simulated Data")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /scratch/local/u0881097/2226036/ipykernel_3687420/3076427330.py in <cell line: 4>()
#       2
#       3 # Load your simulated data
# ----> 4 s = Spectrum(["spec_files/FPMA_nH20_F12_360s_6_bkg.pha", "spec_files/FPMA_nH20_F12_360s_6.pha"])
#       5
#       6 s1 = Spectrum("file1")
#
# /uufs/chpc.utah.edu/sys/installdir/r8/heasoft/6.31.1/x86_64-pc-linux-gnu-libc2.28/lib/python/xspec/spectrum.py in __init__(self, dataFile, backFile, respFile, arfFile)
#     196             self.__handle = dataFile
#     197         else:
# --> 198             self.__handle = _pyXspec.readSpectrum(dataFile)
#     199         self.__detArray = _DetArrayEmulator(self.__handle)
#     200         specIdx = _pyXspec.getIndexFromHandle(self.__handle)
#
# Exception: Filename parsing error
